# %%
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd

import scipy as sp
import scipy.stats as sps

import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

# %%
elec = pd.read_csv('../00. Data/elec.csv')
info = pd.read_csv('../00. Data/info.csv')

# %%
elec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24672 entries, 0 to 24671
# Data columns (total 4 columns):
# Date        24672 non-null object
# DateHour    24672 non-null object
# Minute      24672 non-null object
# Value       24672 non-null int64
# dtypes: int64(1), object(3)
# memory usage: 771.1+ KB

# %%
elec
# Out:
#                       Date             DateHour Minute  Value
# 0      2021-01-01 00:15:00  2021-01-01 00:00:00    15분     62
# 1      2021-01-01 00:30:00  2021-01-01 00:00:00    30분     61
# 2      2021-01-01 00:45:00  2021-01-01 00:00:00    45분     61
# 3      2021-01-01 01:00:00  2021-01-01 00:00:00    60분     61
# 4      2021-01-01 01:15:00  2021-01-01 01:00:00    15분     96
# ...                    ...                  ...    ...    ...
# 24667  2021-09-14 23:00:00  2021-09-14 22:00:00    60분    114
# 24668  2021-09-14 23:15:00  2021-09-14 23:00:00    15분    117
# 24669  2021-09-14 23:30:00  2021-09-14 23:00:00    30분    119
# 24670  2021-09-14 23:45:00  2021-09-14 23:00:00    45분    112
# 24671  2021-09-15 00:00:00  2021-09-14 23:00:00    60분     91
#
# [24672 rows x 4 columns]

# %%
info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6168 entries, 0 to 6167
# Data columns (total 9 columns):
# Date        6168 non-null object
# 생산량         6168 non-null int64
# 기온          6168 non-null float64
# 풍속          6165 non-null float64
# 습도          6168 non-null int64
# 강수량         6167 non-null float64
# 전기요금(계절)    6168 non-null float64
# 공장인원        6151 non-null float64
# 인건비         6168 non-null float64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 433.8+ KB

# %%
elec.Date = pd.to_datetime( elec.Date )
elec.DateHour = pd.to_datetime( elec.DateHour )
info.Date = pd.to_datetime( info.Date )

# %% [markdown]
# # 전처리

# %% [markdown]
# ## 단계 1

# %%
elec1 = elec.pivot_table( index='DateHour', columns='Minute', values='Value' ).reset_index()
elec1
# Out:
# Minute            DateHour  15분  30분  45분  60분
# 0      2021-01-01 00:00:00   62   61   61   61
# 1      2021-01-01 01:00:00   96   93  116  113
# 2      2021-01-01 02:00:00  106   96  106  107
# 3      2021-01-01 03:00:00   92  110  110  109
# 4      2021-01-01 04:00:00  108  105  106  108
# ...                    ...  ...  ...  ...  ...
# 6163   2021-09-14 19:00:00  152  151  171  139
# 6164   2021-09-14 20:00:00  124  130  128  130
# 6165   2021-09-14 21:00:00  134  130  125  124
# 6166   2021-09-14 22:00:00  100  109  120  114
# 6167   2021-09-14 23:00:00  117  119  112   91
#
# [6168 rows x 5 columns]

# %% [markdown]
# ## 단계 2

# %%
elec1['DayName'] = elec1.DateHour.dt.dayofweek
elec1['Hour'] = elec1.DateHour.dt.hour
elec1['AM'] = np.where( elec1.Hour < 12, 0, 1 )
elec1['Weekend_yn'] = elec1['DayName'].apply( lambda x: 1 if x==5 or x==6 else 0 )

holiday_list = ["2021-01-01", "2021-02-11", "2021-02-12", "2021-03-01", "2021-05-05", "2021-05-19", "2021-08-16"]
elec1['Holiday_yn'] = np.where( elec1.DateHour.dt.date.astype(str).isin(holiday_list), 1, 0 )

# loc은 마지막 인덱스에 대해서 닫혀 있습니다.(포함)
elec1['Avg'] = elec1.loc[ :, '15분':'60분' ].mean( axis=1 )

# iloc은 마지막 인덱스에 대해서 열려 있습니다(미포함)
elec1['TotalHour'] = elec1.iloc[ : , 1:5 ].sum( axis=1 )
elec1
# Out:
# Minute            DateHour  15분  30분  45분  60분  DayName  Hour  AM  Weekend_yn  \
# 0      2021-01-01 00:00:00   62   61   61   61        4     0   0           0
# 1      2021-01-01 01:00:00   96   93  116  113        4     1   0           0
# 2      2021-01-01 02:00:00  106   96  106  107        4     2   0           0
# 3      2021-01-01 03:00:00   92  110  110  109        4     3   0           0
# 4      2021-01-01 04:00:00  108  105  106  108        4     4   0           0
# ...                    ...  ...  ...  ...  ...      ...   ...  ..         ...
# 6163   2021-09-14 19:00:00  152  151  171  139        1    19   1           0
# 6164   2021-09-14 20:00:00  124  130  128  130        1    20   1           0
# 6165   2021-09-14 21:00:00  134  130  125  124        1    21   1           0
# 6166   2021-09-14 22:00:00  100  109  120  114        1    22   1           0
# 6167   2021-09-14 23:00:00  117  119  112   91        1    23   1           0
#
# Minute  Holiday_yn     Avg  TotalHour
# 0                1   61.25        245
# 1                1  104.50        418
# 2                1  103.75        415
# 3                1  105.25        421
# 4                1  106.75        427
# ...            ...     ...        ...
# 6163             0  153.25        613
# 6164             0  128.00        512
# 6165             0  128.25        513
# 6166             0  110.75        443
# 6167             0  109.75        439
#
# [6168 rows x 12 columns]

# %% [markdown]
# ## 단계 3

# %%
info1 = info.fillna(0).copy()
info1
# Out:
#                     Date   생산량    기온   풍속  습도  강수량  전기요금(계절)      공장인원  인건비
# 0    2021-01-01 00:00:00     0  -3.2  2.4  71  0.0     109.8  0.000000  1.5
# 1    2021-01-01 01:00:00     0  -4.5  1.5  77  0.0     109.8  0.000000  1.5
# 2    2021-01-01 02:00:00     0  -3.9  2.6  58  0.0     109.8  0.000000  1.5
# 3    2021-01-01 03:00:00     0  -4.1  2.6  56  0.0     109.8  0.000000  1.5
# 4    2021-01-01 04:00:00     0  -4.6  2.6  60  0.0     109.8  0.000000  1.5
# ...                  ...   ...   ...  ...  ..  ...       ...       ...  ...
# 6163 2021-09-14 19:00:00  1497  21.7  3.6  85  9.4     167.2  2.442088  1.5
# 6164 2021-09-14 20:00:00    45  22.2  4.2  78  9.4     167.2  0.087891  1.5
# 6165 2021-09-14 21:00:00   149  22.2  4.3  76  9.4     167.2  0.290448  1.5
# 6166 2021-09-14 22:00:00    66  22.0  2.5  79  9.4     167.2  0.148984  1.5
# 6167 2021-09-14 23:00:00   405  22.0  2.5  79  9.4     167.2  0.922551  1.5
#
# [6168 rows x 9 columns]

# %% [markdown]
# ## 단계 4

# %%
basetable1 = pd.merge( left=elec1, right=info1, left_on='DateHour', right_on='Date', how='inner' ).drop( columns=['Date'] )
basetable1
# Out:
#                 DateHour  15분  30분  45분  60분  DayName  Hour  AM  Weekend_yn  \
# 0    2021-01-01 00:00:00   62   61   61   61        4     0   0           0
# 1    2021-01-01 01:00:00   96   93  116  113        4     1   0           0
# 2    2021-01-01 02:00:00  106   96  106  107        4     2   0           0
# 3    2021-01-01 03:00:00   92  110  110  109        4     3   0           0
# 4    2021-01-01 04:00:00  108  105  106  108        4     4   0           0
# ...                  ...  ...  ...  ...  ...      ...   ...  ..         ...
# 6163 2021-09-14 19:00:00  152  151  171  139        1    19   1           0
# 6164 2021-09-14 20:00:00  124  130  128  130        1    20   1           0
# 6165 2021-09-14 21:00:00  134  130  125  124        1    21   1           0
# 6166 2021-09-14 22:00:00  100  109  120  114        1    22   1           0
# 6167 2021-09-14 23:00:00  117  119  112   91        1    23   1           0
#
#       Holiday_yn     Avg  TotalHour   생산량    기온   풍속  습도  강수량  전기요금(계절)  \
# 0              1   61.25        245     0  -3.2  2.4  71  0.0     109.8
# 1              1  104.50        418     0  -4.5  1.5  77  0.0     109.8
# 2              1  103.75        415     0  -3.9  2.6  58  0.0     109.8
# 3              1  105.25        421     0  -4.1  2.6  56  0.0     109.8
# 4              1  106.75        427     0  -4.6  2.6  60  0.0     109.8
# ...          ...     ...        ...   ...   ...  ...  ..  ...       ...
# 6163           0  153.25        613  1497  21.7  3.6  85  9.4     167.2
# 6164           0  128.00        512    45  22.2  4.2  78  9.4     167.2
# 6165           0  128.25        513   149  22.2  4.3  76  9.4     167.2
# 6166           0  110.75        443    66  22.0  2.5  79  9.4     167.2
# 6167           0  109.75        439   405  22.0  2.5  79  9.4     167.2
#
#           공장인원  인건비
# 0     0.000000  1.5
# 1     0.000000  1.5
# 2     0.000000  1.5
# 3     0.000000  1.5
# 4     0.000000  1.5
# ...        ...  ...
# 6163  2.442088  1.5
# 6164  0.087891  1.5
# 6165  0.290448  1.5
# 6166  0.148984  1.5
# 6167  0.922551  1.5
#
# [6168 rows x 20 columns]

# %% [markdown]
# # 문제 1

# %% [markdown]
# ## 문제 1-1

# %%
basetable1.TotalHour.max() - basetable1.TotalHour.min()
# Out:
# 830

# %% [markdown]
# ## 문제 1-2

# %%
basetable1.DateHour
# Out:
# 0      2021-01-01 00:00:00
# 1      2021-01-01 01:00:00
# 2      2021-01-01 02:00:00
# 3      2021-01-01 03:00:00
# 4      2021-01-01 04:00:00
#                ...
# 6163   2021-09-14 19:00:00
# 6164   2021-09-14 20:00:00
# 6165   2021-09-14 21:00:00
# 6166   2021-09-14 22:00:00
# 6167   2021-09-14 23:00:00
# Name: DateHour, Length: 6168, dtype: datetime64[ns]

# %%
basetable1.loc[ basetable1.groupby(basetable1.DateHour.dt.date)['TotalHour']
    .transform( lambda x : x == x.max()), 'Hour' ].value_counts()
# Out:
# 8     57
# 11    48
# 13    31
# 9     28
# 4     26
# 23    16
# 0     15
# 14    14
# 10     9
# 2      9
# 16     8
# 17     5
# 6      5
# 21     5
# 12     4
# 1      4
# 7      3
# 15     2
# 3      2
# 22     1
# 18     1
# Name: Hour, dtype: int64

# %%
basetable1.groupby( basetable1.DateHour.dt.date )\
    .apply( lambda x : x.loc[ x.TotalHour.idxmax(), 'Hour'] ).value_counts()
# Out:
# 8     57
# 11    42
# 9     28
# 13    28
# 4     25
# 0     15
# 14    12
# 2      9
# 10     8
# 16     7
# 6      5
# 17     5
# 1      4
# 12     3
# 21     3
# 3      2
# 22     1
# 15     1
# 7      1
# 23     1
# dtype: int64

# %% [markdown]
# ## 문제 1-3

# %%
( basetable1.groupby( basetable1.DateHour.dt.date )['TotalHour'].max() - \
basetable1.groupby( basetable1.DateHour.dt.date )['TotalHour'].min() ).max()
# Out:
# 706

# %% [markdown]
# ## 문제 1-4

# %%
weekday = basetable1[ (basetable1.Weekend_yn == 0) & (basetable1.Holiday_yn == 0) ].copy()

# %%
( weekday.groupby( weekday.DateHour.dt.date )['TotalHour'].max() - 
weekday.groupby( weekday.DateHour.dt.date )['TotalHour'].min() ).sort_values( ascending=False )
# Out:
# DateHour
# 2021-07-19    706
# 2021-07-26    697
# 2021-08-09    692
# 2021-07-12    677
# 2021-01-21    669
#              ...
# 2021-08-03     12
# 2021-03-26     12
# 2021-08-05     11
# 2021-08-04     11
# 2021-08-02     11
# Name: TotalHour, Length: 176, dtype: int64

# %%
weekday.loc[ weekday.DateHour == '2021-07-19', 'DayName' ]
# Out:
# 4776    0
# Name: DayName, dtype: int64

# %% [markdown]
# ## 정답

# %%
print( 830, 8, 706, '2021-07-19', '월요일' )
# Out:
# 830 8 706 2021-07-19 월요일

# %% [markdown]
# # 문제 2

# %%
am = weekday.loc[ weekday.AM == 0, 'Avg']
pm = weekday.loc[ weekday.AM == 1, 'Avg']

# %%
_, pvalue = sps.bartlett( am, pm )
pvalue
# Out:
# 6.451706909079159e-17

# %%
ans = sps.ttest_ind( am, pm, equal_var= pvalue > 0.05 ).statistic
ans
# Out:
# -11.659445083355282

# %%
round( abs(ans), 3 )
# Out:
# 11.659

# %% [markdown]
# # 문제 3

# %%
train1 = elec.loc[ elec.Date < '2021-09-01', ['Date', 'Value'] ]
test1 = elec.loc[ elec.Date >= '2021-09-01', ['Date', 'Value'] ]

# %%
train1['t-2'] = train1.Value.shift(-1)
train1['t-1'] = train1.Value.shift(-2)
train1['t-0'] = train1.Value.shift(-3)

# %%
for i in range(-1, -4, -1):
    train1[ f't-{3+i}' ] = train1.Value.shift(i)

# %%
for i in range(-1, -4, -1):
    test1[ f't-{3+i}' ] = test1.Value.shift(i)

# %%
train1 = train1.rename( columns={'Value':'t-3', 't-0':'target'} )
test1 = test1.rename( columns={'Value':'t-3', 't-0':'target'} )

# %%
train1 = train1.dropna()
test1 = test1.dropna()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

# %%
x_train = train1.iloc[ :, 1:4 ]
x_test = test1.iloc[ :, 1:4 ]

# %%
y_train = train1['target']
y_test = test1['target']

# %%
lm1 = LinearRegression().fit( x_train, y_train )

# %%
y_hat = lm1.predict( x_test )
mae = mean_absolute_error( y_test, y_hat )
round( mae, 2 )
# Out:
# 8.97

# %% [markdown]
# # 문제 4

# %%
train2 = elec.loc[ elec.Date < '2021-09-01', ['Date', 'Value'] ]
test2 = elec.loc[ elec.Date >= '2021-09-01', ['Date', 'Value'] ]

# %%
for i in range(-1, -96, -1):
    train2[ f't-{95+i}' ] = train2.Value.shift(i)
    test2[ f't-{95+i}' ] = test2.Value.shift(i)

# %%
train2
# Out:
#                      Date  Value   t-94   t-93   t-92   t-91   t-90   t-89  \
# 0     2021-01-01 00:15:00     62   61.0   61.0   61.0   96.0   93.0  116.0
# 1     2021-01-01 00:30:00     61   61.0   61.0   96.0   93.0  116.0  113.0
# 2     2021-01-01 00:45:00     61   61.0   96.0   93.0  116.0  113.0  106.0
# 3     2021-01-01 01:00:00     61   96.0   93.0  116.0  113.0  106.0   96.0
# 4     2021-01-01 01:15:00     96   93.0  116.0  113.0  106.0   96.0  106.0
# ...                   ...    ...    ...    ...    ...    ...    ...    ...
# 23322 2021-08-31 22:45:00    127  112.0  103.0  128.0  118.0    NaN    NaN
# 23323 2021-08-31 23:00:00    112  103.0  128.0  118.0    NaN    NaN    NaN
# 23324 2021-08-31 23:15:00    103  128.0  118.0    NaN    NaN    NaN    NaN
# 23325 2021-08-31 23:30:00    128  118.0    NaN    NaN    NaN    NaN    NaN
# 23326 2021-08-31 23:45:00    118    NaN    NaN    NaN    NaN    NaN    NaN
#
#         t-88   t-87  ...   t-9   t-8   t-7   t-6   t-5   t-4   t-3   t-2  \
# 0      113.0  106.0  ...  22.0  27.0  26.0  22.0  22.0  22.0  22.0  22.0
# 1      106.0   96.0  ...  27.0  26.0  22.0  22.0  22.0  22.0  22.0  22.0
# 2       96.0  106.0  ...  26.0  22.0  22.0  22.0  22.0  22.0  22.0  22.0
# 3      106.0  107.0  ...  22.0  22.0  22.0  22.0  22.0  22.0  22.0  63.0
# 4      107.0   92.0  ...  22.0  22.0  22.0  22.0  22.0  22.0  63.0  63.0
# ...      ...    ...  ...   ...   ...   ...   ...   ...   ...   ...   ...
# 23322    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 23323    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 23324    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 23325    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 23326    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#         t-1   t-0
# 0      22.0  22.0
# 1      22.0  63.0
# 2      63.0  63.0
# 3      63.0  64.0
# 4      64.0  63.0
# ...     ...   ...
# 23322   NaN   NaN
# 23323   NaN   NaN
# 23324   NaN   NaN
# 23325   NaN   NaN
# 23326   NaN   NaN
#
# [23327 rows x 97 columns]

# %%
train2 = train2.rename( columns={'Value':'t-95', 't-0':'target'} )
test2 = test2.rename( columns={'Value':'t-95', 't-0':'target'} )

# %%
test2
# Out:
#                      Date  t-95   t-94   t-93   t-92   t-91   t-90   t-89  \
# 23327 2021-09-01 00:00:00   100   83.0   74.0   69.0   68.0   98.0  107.0
# 23328 2021-09-01 00:15:00    83   74.0   69.0   68.0   98.0  107.0  117.0
# 23329 2021-09-01 00:30:00    74   69.0   68.0   98.0  107.0  117.0  114.0
# 23330 2021-09-01 00:45:00    69   68.0   98.0  107.0  117.0  114.0  121.0
# 23331 2021-09-01 01:00:00    68   98.0  107.0  117.0  114.0  121.0  118.0
# ...                   ...   ...    ...    ...    ...    ...    ...    ...
# 24667 2021-09-14 23:00:00   114  117.0  119.0  112.0   91.0    NaN    NaN
# 24668 2021-09-14 23:15:00   117  119.0  112.0   91.0    NaN    NaN    NaN
# 24669 2021-09-14 23:30:00   119  112.0   91.0    NaN    NaN    NaN    NaN
# 24670 2021-09-14 23:45:00   112   91.0    NaN    NaN    NaN    NaN    NaN
# 24671 2021-09-15 00:00:00    91    NaN    NaN    NaN    NaN    NaN    NaN
#
#         t-88   t-87  ...    t-9    t-8    t-7    t-6    t-5    t-4    t-3  \
# 23327  117.0  114.0  ...  133.0  132.0  126.0  108.0  128.0  119.0  122.0
# 23328  114.0  121.0  ...  132.0  126.0  108.0  128.0  119.0  122.0  119.0
# 23329  121.0  118.0  ...  126.0  108.0  128.0  119.0  122.0  119.0  121.0
# 23330  118.0  111.0  ...  108.0  128.0  119.0  122.0  119.0  121.0  111.0
# 23331  111.0  105.0  ...  128.0  119.0  122.0  119.0  121.0  111.0  103.0
# ...      ...    ...  ...    ...    ...    ...    ...    ...    ...    ...
# 24667    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 24668    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 24669    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 24670    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 24671    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#          t-2    t-1  target
# 23327  119.0  121.0   111.0
# 23328  121.0  111.0   103.0
# 23329  111.0  103.0    87.0
# 23330  103.0   87.0    79.0
# 23331   87.0   79.0    75.0
# ...      ...    ...     ...
# 24667    NaN    NaN     NaN
# 24668    NaN    NaN     NaN
# 24669    NaN    NaN     NaN
# 24670    NaN    NaN     NaN
# 24671    NaN    NaN     NaN
#
# [1345 rows x 97 columns]

# %%
train2 = train2.dropna()
test2 = test2.dropna()

# %%
x_train = train2.iloc[ :, 1:96 ]
x_test = test2.iloc[ :, 1:96 ]

y_train = train2['target']
y_test = test2['target']

# %% [markdown]
# ## 회귀모형 적용 1

# %%
lm2 = LinearRegression().fit( x_train, y_train )

# %%
y_hat = lm2.predict( x_test )
mae1 = mean_absolute_error( y_test, y_hat )
mae1
# Out:
# 7.68969779872557

# %% [markdown]
# ## PCA 적용

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA( n_components=0.99, random_state=123 )

# %%
pca.fit( x_train )
# Out:
# PCA(copy=True, iterated_power='auto', n_components=0.99, random_state=123,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
pca.n_components_
# Out:
# 40

# %%
tr_x2 = pca.transform( x_train )
te_x2 = pca.transform( x_test )

# %% [markdown]
# ##  회귀모형 적용 2

# %%
lm3 = LinearRegression().fit( tr_x2, y_train )

# %%
y_hat = lm3.predict( te_x2 )
mae2 = mean_absolute_error( y_test, y_hat )
mae2
# Out:
# 9.343359300942199

# %%
print( round(mae1, 2), round(mae2, 2))
# Out:
# 7.69 9.34

# %% [markdown]
# # 문제 5

# %% [markdown]
# ## SVM 적용

# %%
from sklearn.svm import SVR

# %%
svr = SVR( C=100 ).fit( tr_x2, y_train )

# %%
y_hat = svr.predict( te_x2 )
mae = mean_absolute_error( y_test, y_hat )
mae
# Out:
# 43.24670670897594

# %% [markdown]
# ## 전기료 산출

# %%
test2.Date = pd.to_datetime( test2.Date.dt.strftime("%Y-%m-%d %H:00:00") )

# %%
fee = pd.merge( left=test2, right=info1, on='Date', how='left')
fee['pred'] = y_hat
fee
# Out:
#                     Date  t-95   t-94   t-93   t-92   t-91   t-90   t-89  \
# 0    2021-09-01 00:00:00   100   83.0   74.0   69.0   68.0   98.0  107.0
# 1    2021-09-01 00:00:00    83   74.0   69.0   68.0   98.0  107.0  117.0
# 2    2021-09-01 00:00:00    74   69.0   68.0   98.0  107.0  117.0  114.0
# 3    2021-09-01 00:00:00    69   68.0   98.0  107.0  117.0  114.0  121.0
# 4    2021-09-01 01:00:00    68   98.0  107.0  117.0  114.0  121.0  118.0
# ...                  ...   ...    ...    ...    ...    ...    ...    ...
# 1245 2021-09-13 23:00:00   111  123.0  110.0   87.0   72.0   70.0   70.0
# 1246 2021-09-13 23:00:00   123  110.0   87.0   72.0   70.0   70.0   67.0
# 1247 2021-09-13 23:00:00   110   87.0   72.0   70.0   70.0   67.0   98.0
# 1248 2021-09-14 00:00:00    87   72.0   70.0   70.0   67.0   98.0  116.0
# 1249 2021-09-14 00:00:00    72   70.0   70.0   67.0   98.0  116.0  113.0
#
#        t-88   t-87  ...  target   생산량    기온   풍속  습도  강수량  전기요금(계절)      공장인원  \
# 0     117.0  114.0  ...   111.0   178  21.8  1.7  94  0.0     167.2  0.605442
# 1     114.0  121.0  ...   103.0   178  21.8  1.7  94  0.0     167.2  0.605442
# 2     121.0  118.0  ...    87.0   178  21.8  1.7  94  0.0     167.2  0.605442
# 3     118.0  111.0  ...    79.0   178  21.8  1.7  94  0.0     167.2  0.605442
# 4     111.0  105.0  ...    75.0  1160  21.5  1.5  95  0.0     167.2  2.660550
# ...     ...    ...  ...     ...   ...   ...  ...  ..  ...       ...       ...
# 1245   67.0   98.0  ...   114.0   345  21.4  1.4  80  0.0     167.2  0.800464
# 1246   98.0  116.0  ...   117.0   345  21.4  1.4  80  0.0     167.2  0.800464
# 1247  116.0  113.0  ...   119.0   345  21.4  1.4  80  0.0     167.2  0.800464
# 1248  113.0  113.0  ...   112.0   128  21.9  1.6  80  0.0     167.2  0.458781
# 1249  113.0  115.0  ...    91.0   128  21.9  1.6  80  0.0     167.2  0.458781
#
#       인건비      pred
# 0     1.5  101.1657
# 1     1.5  101.1657
# 2     1.5  101.1657
# 3     1.5  101.1657
# 4     1.5  101.1657
# ...   ...       ...
# 1245  1.5  101.1657
# 1246  1.5  101.1657
# 1247  1.5  101.1657
# 1248  1.5  101.1657
# 1249  1.5  101.1657
#
# [1250 rows x 106 columns]

# %%
target_fee = fee['target'] * fee['전기요금(계절)']
target_fee
# Out:
# 0       18559.2
# 1       17221.6
# 2       14546.4
# 3       13208.8
# 4       12540.0
#          ...
# 1245    19060.8
# 1246    19562.4
# 1247    19896.8
# 1248    18726.4
# 1249    15215.2
# Length: 1250, dtype: float64

# %%
pred_fee = fee['pred'] * fee['전기요금(계절)']
pred_fee
# Out:
# 0       16914.905078
# 1       16914.905078
# 2       16914.905078
# 3       16914.905078
# 4       16914.905078
#             ...
# 1245    16914.905078
# 1246    16914.905078
# 1247    16914.905078
# 1248    16914.905078
# 1249    16914.905078
# Length: 1250, dtype: float64

# %%
fee_ans = int( (target_fee - pred_fee).sum() )
fee_ans
# Out:
# 924410

# %%
print( round(mae, 1), fee_ans )
# Out:
# 43.2 924410

# %% [markdown]
# # 문제 6

# %%
basetable1
# Out:
#                 DateHour  15분  30분  45분  60분  DayName  Hour  AM  Weekend_yn  \
# 0    2021-01-01 00:00:00   62   61   61   61        4     0   0           0
# 1    2021-01-01 01:00:00   96   93  116  113        4     1   0           0
# 2    2021-01-01 02:00:00  106   96  106  107        4     2   0           0
# 3    2021-01-01 03:00:00   92  110  110  109        4     3   0           0
# 4    2021-01-01 04:00:00  108  105  106  108        4     4   0           0
# ...                  ...  ...  ...  ...  ...      ...   ...  ..         ...
# 6163 2021-09-14 19:00:00  152  151  171  139        1    19   1           0
# 6164 2021-09-14 20:00:00  124  130  128  130        1    20   1           0
# 6165 2021-09-14 21:00:00  134  130  125  124        1    21   1           0
# 6166 2021-09-14 22:00:00  100  109  120  114        1    22   1           0
# 6167 2021-09-14 23:00:00  117  119  112   91        1    23   1           0
#
#       Holiday_yn     Avg  TotalHour   생산량    기온   풍속  습도  강수량  전기요금(계절)  \
# 0              1   61.25        245     0  -3.2  2.4  71  0.0     109.8
# 1              1  104.50        418     0  -4.5  1.5  77  0.0     109.8
# 2              1  103.75        415     0  -3.9  2.6  58  0.0     109.8
# 3              1  105.25        421     0  -4.1  2.6  56  0.0     109.8
# 4              1  106.75        427     0  -4.6  2.6  60  0.0     109.8
# ...          ...     ...        ...   ...   ...  ...  ..  ...       ...
# 6163           0  153.25        613  1497  21.7  3.6  85  9.4     167.2
# 6164           0  128.00        512    45  22.2  4.2  78  9.4     167.2
# 6165           0  128.25        513   149  22.2  4.3  76  9.4     167.2
# 6166           0  110.75        443    66  22.0  2.5  79  9.4     167.2
# 6167           0  109.75        439   405  22.0  2.5  79  9.4     167.2
#
#           공장인원  인건비
# 0     0.000000  1.5
# 1     0.000000  1.5
# 2     0.000000  1.5
# 3     0.000000  1.5
# 4     0.000000  1.5
# ...        ...  ...
# 6163  2.442088  1.5
# 6164  0.087891  1.5
# 6165  0.290448  1.5
# 6166  0.148984  1.5
# 6167  0.922551  1.5
#
# [6168 rows x 20 columns]

# %%
df = basetable1.loc[ basetable1.생산량 != 0 ]
df
# Out:
#                 DateHour  15분  30분  45분  60분  DayName  Hour  AM  Weekend_yn  \
# 80   2021-01-04 08:00:00  154  153  159  159        0     8   0           0
# 81   2021-01-04 09:00:00  158  158  159  166        0     9   0           0
# 82   2021-01-04 10:00:00  127  158  173  168        0    10   0           0
# 83   2021-01-04 11:00:00  141  150  155  149        0    11   0           0
# 84   2021-01-04 12:00:00   81   64   94  118        0    12   1           0
# ...                  ...  ...  ...  ...  ...      ...   ...  ..         ...
# 6163 2021-09-14 19:00:00  152  151  171  139        1    19   1           0
# 6164 2021-09-14 20:00:00  124  130  128  130        1    20   1           0
# 6165 2021-09-14 21:00:00  134  130  125  124        1    21   1           0
# 6166 2021-09-14 22:00:00  100  109  120  114        1    22   1           0
# 6167 2021-09-14 23:00:00  117  119  112   91        1    23   1           0
#
#       Holiday_yn     Avg  TotalHour   생산량    기온   풍속  습도  강수량  전기요금(계절)  \
# 80             0  156.25        625   165  -2.7  4.1  53  0.0     109.8
# 81             0  160.25        641   313  -1.5  2.4  48  0.0     109.8
# 82             0  156.50        626  2757   0.4  2.4  39  0.0     109.8
# 83             0  148.75        595   983   2.1  2.5  31  0.0     109.8
# 84             0   89.25        357    96   4.0  3.3  30  0.0     109.8
# ...          ...     ...        ...   ...   ...  ...  ..  ...       ...
# 6163           0  153.25        613  1497  21.7  3.6  85  9.4     167.2
# 6164           0  128.00        512    45  22.2  4.2  78  9.4     167.2
# 6165           0  128.25        513   149  22.2  4.3  76  9.4     167.2
# 6166           0  110.75        443    66  22.0  2.5  79  9.4     167.2
# 6167           0  109.75        439   405  22.0  2.5  79  9.4     167.2
#
#           공장인원  인건비
# 80    0.264000  1.5
# 81    0.488300  1.0
# 82    4.404153  1.0
# 83    1.652101  1.0
# 84    0.268908  1.0
# ...        ...  ...
# 6163  2.442088  1.5
# 6164  0.087891  1.5
# 6165  0.290448  1.5
# 6166  0.148984  1.5
# 6167  0.922551  1.5
#
# [3511 rows x 20 columns]

# %%
train3 = df[ df.DateHour < '2021-09-01' ]
test3 = df[ df.DateHour >= '2021-09-01' ]

# %%
x_train3 = train3.drop( columns=['생산량', 'DateHour'] )
x_test3 = test3.drop( columns=['생산량', 'DateHour'] )

y_train3 = train3['생산량']
y_test3 = test3['생산량']

print( x_train3.shape, x_test3.shape, y_train3.shape, y_test3.shape )
# Out:
# (3277, 18) (234, 18) (3277,) (234,)

# %%
baseModel = LinearRegression().fit(x_train3, y_train3)

# %%
y_hat = baseModel.predict( x_train3 )
print( mean_absolute_error(y_train3, y_hat ) )

y_hat = baseModel.predict( x_test3 )
mean_absolute_error( y_test3, y_hat )
# Out:
# 291.107621883913
# 242.450981641306

# %%
pd.concat( [ pd.DataFrame( baseModel.coef_, columns=['coef'] ), 
            pd.DataFrame( x_train3.columns, columns=['feature'] ) ], axis=1 )\
            .sort_values( by='coef' )
# Out:
#             coef     feature
# 10 -6.217194e+13   TotalHour
# 9  -1.572740e+13         Avg
# 5  -2.595862e+01        Hour
# 4  -1.976842e+01     DayName
# 11 -3.223022e+00          기온
# 14 -2.235718e-01         강수량
# 13 -2.196045e-01          습도
# 15  2.367676e+00    전기요금(계절)
# 12  5.535217e+00          풍속
# 8   1.360444e+01  Holiday_yn
# 7   1.189644e+02  Weekend_yn
# 17  1.769122e+02         인건비
# 16  3.022576e+02        공장인원
# 6   3.982114e+02          AM
# 1   6.610379e+13         30분
# 3   6.610379e+13         60분
# 0   6.610379e+13         15분
# 2   6.610379e+13         45분

# %%
from sklearn.linear_model import ElasticNet

# %%
elastic = ElasticNet( l1_ratio=1.0, normalize=True, alpha=0.0001 ).fit( x_train3, y_train3 )

# %%
y_hat = elastic.predict( x_test3 )
mean_absolute_error( y_test3, y_hat )
# Out:
# 238.66187453469541

# %%
pd.concat( [ pd.DataFrame( elastic.coef_, columns=['coef'] ), 
            pd.DataFrame( x_train3.columns, columns=['feature'] ) ], axis=1 )\
            .sort_values( by='coef' )
# Out:
#           coef     feature
# 5   -25.974936        Hour
# 4   -19.610646     DayName
# 9    -3.873999         Avg
# 11   -3.213567          기온
# 1    -0.267677         30분
# 13   -0.228143          습도
# 14   -0.213495         강수량
# 10   -0.000000   TotalHour
# 3     0.099054         60분
# 15    2.387617    전기요금(계절)
# 12    5.154429          풍속
# 0     7.397997         15분
# 2     8.891924         45분
# 8    14.109066  Holiday_yn
# 7   118.980195  Weekend_yn
# 17  175.113627         인건비
# 16  302.215431        공장인원
# 6   398.751824          AM

# %%
from xgboost import XGBRegressor

# %%
model = XGBRegressor( max_depth=5, n_estimators=3000,  ).fit( x_train3, y_train3 )

# %%
y_hat = model.predict( x_train3 )
print( mean_absolute_error(y_train3, y_hat ) )

y_hat = model.predict( x_test3 )
mean_absolute_error( y_test3, y_hat )
# Out:
# 0.04616957639170959
# 12.264791529402773

# %%
svr = SVR( C=10000 ).fit( x_train3[['공장인원', 'Avg', 'TotalHour']], y_train3 )

# %%
y_hat = svr.predict( x_train3[['공장인원', 'Avg', 'TotalHour']] )
print( mean_absolute_error(y_train3, y_hat ) )

y_hat = svr.predict( x_test3[['공장인원', 'Avg', 'TotalHour']] )
mean_absolute_error( y_test3, y_hat )
# Out:
# 0.6043732443698959
# 70.82578808399498
